# %% [markdown]
# # Assignment on Store_sales dataset
#
# **Load the Dataset**

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\Lenovo\Downloads\store_sales.csv")
df
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# 1    21   19
# 2    24    8
# ...

# %% [markdown]
# **Calculate the total sales for each store across all months.**

# %%
#totsales=df.groupby('city')[[['Jan']['Feb']['Mar']['Apr']['May']['Jun']['July']['Aug']['Sep']['Oct']['Nov']['Dec']]].sum()
#otsales

totsales = df.groupby('store_id')[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                               'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].sum().sum(axis=1)
print(totsales)
#sum(axis=1) then we get summed up total
# Out:
# store_id
# S_1      178
# S_10     178
# S_100    180
# S_11     196
# S_12     164
#         ...
# S_95     176
# S_96     185
# S_97     154
# S_98     168
# S_99     173
# Length: 100, dtype: int64

# %% [markdown]
# **Find the average sales for each month across all stores**

# %%
#avgsales = df.[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                              # 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].mean(axis=1)
#print(avgsales)

# Calculate the average sales per store across all months
df['Average Sales'] = df[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].mean(axis=1)

# Display the store ID and their corresponding average sales
print(df[['store_id', 'Average Sales']])
# Out:
#    store_id  Average Sales
# 0       S_1      14.833333
# 1       S_2      14.500000
# 2       S_3      15.083333
# 3       S_4      11.250000
# 4       S_5      13.250000
# ..      ...            ...
# 95     S_96      15.416667
# 96     S_97      12.833333
# 97     S_98      14.000000
# 98     S_99      14.416667
# 99    S_100      15.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# **Identify the store with the highest total sales.**

# %%
strid = df.groupby('storeid')[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                               'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].sum()
strid
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-aaef2244d412> in <module>
# ----> 1 strid = df.groupby('storeid')[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#       2                                'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].sum()
#       3 strid
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %% [markdown]
# **Calculate the total sales for each city.**

# %%
tot=df.groupby('city')[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                               'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].sum().sum(axis=1)
tot
# Out:
# city
# Arizona       3951
# California    7522
# Texas         5939
# dtype: int64

# %% [markdown]
# **List stores with total sales greater than 200**

# %%
totgt200 = df[df[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].sum(axis=1)>200]
totgt200
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 37     S_38  California   21   10   13   11   11   14    24   24   24   21
# 39     S_40       Texas   22   21   13   13   14   15     6   24   16   23
# 50     S_51     Arizona   17   23   14   19   23   12    20   21   13   18
# 61     S_62  California   16   21    6   22   22    9    21   21   22   17
# 69     S_70       Texas   24   16   24   20   14   21    15   13   18   22
# 72     S_73  California   20   24   24   18    7   22    12   21   20   18
# 77     S_78     Arizona   19   23   19   24   13   12    24   17   22   16
# 85     S_86  California   15   23   24   18   21   17    23   13   12   11
# 86     S_87       Texas   19   20   10   13   12    5    20   23   21   14
# 92     S_93  California   20   13   15   12   15   19    21   22   10   21
#
#     Nov  Dec  Average Sales
# 37   16   18      17.250000
# 39   13   24      17.000000
# 50    6   24      17.500000
# ...

# %% [raw]
# **Which month had the highest average sales across all stores?**

# %% [markdown]
# **Which city generated the most revenue?**

# %%
totsales = df.groupby('city')[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                               'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].sum().sum(axis=1)
totsales.max()
totsales
# Out:
# city
# Arizona       3951
# California    7522
# Texas         5939
# dtype: int64
